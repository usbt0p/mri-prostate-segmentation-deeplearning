# %% [markdown]
# # Prostate158 dataset exploration

# %%
import os
from os.path import join
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
import random
import pandas as pd
import SimpleITK as sitk
import numpy as np

from exploratoryAnalysis.DataAnalyzer import DataAnalyzer
from time import perf_counter

DATA_ROOT = "/home/guest/work/Datasets"

paths = {
    "158_train" : "prostate158/prostate158_train/train",
    "158_test" : "prostate158/prostate158_test/test"
}

analyzer = DataAnalyzer(DATA_ROOT)

# %% [markdown]
# > Every patient case will at least have three imaging sequences: axial T2W, axial DWI and axial ADC scans (i.e. files ending in _t2w.mha, _hbv.mha, _adc.mha). Additionally, they can also have either, both or none of these optional imaging sequences: sagittal and coronal T2W scans (i.e. files ending in _sag.mha, _cor.mha here).

# %% [markdown]
# Let's see what's inside each patient's dir

# %%
def dirs_by_file_count(pth):
    """
    Returns a dictionary where keys are the number of files in each directory
    and values are lists of directories with that number of files.
    """
    
    bins = dict()
    total = 0

    for dir in analyzer.get_dirs(pth):
        # check if they all have 5 files
        rel = os.path.join(pth, dir)
        
        files = analyzer.get_files(rel)
        key = len(list(files))
        
        # ensure the key exists 
        if key not in bins:
            bins[key] = []
        
        bins[key].append(dir)
        total += 1

    print(f"Processed {total} dirs")

    return bins

# %%
# plot the previous bins
pth = os.path.join(paths["158_train"])
bins = dirs_by_file_count(pth)

plt.figure(figsize=(6, 4))
plt.bar(bins.keys(), [len(v) for v in bins.values()], color='blue', alpha=0.7)
plt.xlabel('Number of Files')
plt.ylabel('Number of Directories')
plt.title(f'Distribution of Number of Files in {pth}')
plt.xticks(list(bins.keys()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()
# Out:
# Processed 139 dirs

# %%
# plot the previous bins
pth = os.path.join(paths["158_test"])
bins = dirs_by_file_count(pth)

plt.figure(figsize=(6, 4))
plt.bar(bins.keys(), [len(v) for v in bins.values()], color='blue', alpha=0.7)
plt.xlabel('Number of Files')
plt.ylabel('Number of Directories')
plt.title(f'Distribution of Number of Files in {pth}')
plt.xticks(list(bins.keys()))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()
# Out:
# Processed 19 dirs

# %% [markdown]
# Some dirs in the train set are missing. The differences in files are due to the extra reader in the test files. In train some have reads for tumors / an empty nii.gz file, but all t2w images and t2w reads (labels).
#
# Now, we plot some of the images. We also need to see how each zone is labeled. (pz=1 or 2, tz=1 or 2, etc.)
#
# **As we see, the TZ is labeled as 2 and the PZ as 1.**

# %%
# pick a random folder and set the name of a file inside as the prefix
d = paths["158_train"]
dirs = list(analyzer.get_dirs(d))
random_dir = random.choice(dirs)
files_in_dir = analyzer.get_files(join(d, random_dir), "(t2\..*)|(t2_anatomy.*)")

# we have to do this because get files is a generator
name = list(files_in_dir)
i1 = join(d, random_dir, name[0])
i2 = join(d, random_dir, name[1])

analyzer.show_image(i1, i2, save="../combined_images.png")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_3663146/2708784779.py:5: SyntaxWarning: invalid escape sequence '\.'
#   files_in_dir = analyzer.get_files(join(d, random_dir), "(t2\..*)|(t2_anatomy.*)")

# %% [markdown]
# Let's look for possible empty masks, since some of the lesion data was missing

# %%
train = paths['158_train']

# Check for empty masks in the training set
non_empty_count = 0
empty_masks = []
for dir in analyzer.get_dirs(train):
    
    name = analyzer.get_files(join(train, dir), "t2_anatomy.*")
    mask_path = join(train, dir, list(name)[0])
    
    # Check if the mask is empty
    if analyzer.is_empty_mask(mask_path):
        print("hello")
        empty_masks.append(mask_path)
    else:
        non_empty_count += 1

print(f"{non_empty_count} out of {non_empty_count+len(empty_masks)} masks are non-empty (contain a segmentation).")
print("Empty mask files:", empty_masks)
# Out:
# 139 out of 139 masks are non-empty (contain a segmentation).
# Empty mask files: []

# %% [markdown]
# Now, we use the function the analyzer to analyze the metadata.

# %%
# use this regex to filter the files
analyzer.regex = "t2.nii.gz"

start = perf_counter()
df = analyzer.collect_metadata_from_subdirs(paths['158_train'])
print(df)
print(perf_counter() - start, "seconds")
# Out:
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/064/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdo\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/121/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\xd5'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/063/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fl\x9d'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/062/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|^'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/097/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdk\xbcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/075/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbc\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/107/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9d\x7f\x9cW'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/083/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9cV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/125/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xdcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/029/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fl\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/038/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/027/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/119/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xdcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/039/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9d}\x9c\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/065/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xb8\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/123/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdw\x9c]'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/048/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\xa5'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/153/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\x98\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/023/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\x97'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/053/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xd8]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/134/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbc\x96'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/095/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xdcU'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/058/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp\x9e'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/154/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/098/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xdcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/022/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm\xbc\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/020/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x98V'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/136/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdq\x9cU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/146/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/035/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9d\x7f|\xd6'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/118/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp\xa5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/055/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\x9c'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/087/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9c\x96'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/099/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9c\xd5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/114/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp\xdd'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/024/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xfc\x97'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/091/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|U'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/102/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7ft]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/129/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9cU'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/070/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm|]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/148/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/094/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbc\x96'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/142/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xb8\x96'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/044/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdi\xd8\\'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/139/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/112/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/046/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/090/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm\x9c\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/127/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdq\xb8\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/061/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdml\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/126/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdmp]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/084/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9d\x7f|\xd5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/041/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x95'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/069/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9cV'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/056/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9c\x9f'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/028/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xb8V'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/132/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\xd5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/144/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|V'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/152/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\xd7'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/036/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9cU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/140/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdi\x98]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/079/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\xde'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/155/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xb8U'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/116/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/103/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdk\xfc]'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/111/t2.nii.gz: b'\x1f\x8b\x08\x08xL\xaea\x00\x03t2.ni'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/032/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\xd7'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/049/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x94\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/081/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xfc\xd7'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/113/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm\xdc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/105/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcW'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/080/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fx\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/149/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbc\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/059/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/042/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9d\x7f\x9cU'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/131/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xb8W'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/082/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdqt]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/071/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm|]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/057/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9cU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/074/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xdc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/157/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/072/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdc]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/025/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdo\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/089/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdcf'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/101/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x8c\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/037/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x98\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/033/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdg\xfce'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/093/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/130/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\x9c\xd7'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/051/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fxV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/150/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdm\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/151/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/021/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdy\xbc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/143/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcW'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/133/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/110/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/104/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcW'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/050/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbcV'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/106/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7ft\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/031/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/158/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/060/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdi\xd8\\'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/135/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x94\xd5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/128/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/077/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdy\xdc\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/117/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/078/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7ft^'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/040/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x98U'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/076/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdo\xbc\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/096/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/086/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/067/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7fp\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/034/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/092/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcV'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/085/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\x9c\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/073/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbcV'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/141/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdc\x95'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/145/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdo|]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/109/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\xd5'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/137/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x94V'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/068/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\x9dy\xdcU'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/088/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\x97'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/052/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdk\xdc\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/066/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x94\xd6'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/156/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xbc\x95'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/138/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\x9c\x95'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/045/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd}\xbcV'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/043/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9c\x96'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/115/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\x9c\x96'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/030/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f\xb8\x95'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/047/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd\x7f|\x9d'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/100/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\x94'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/147/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdy\xdc\x96'...
#
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/120/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdat]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/026/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\\'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/122/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdw\xbc]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/054/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbdw\xb8]'...
# Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/124/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xfc\xd5'...Error decoding line in /home/guest/work/Datasets/prostate158/prostate158_train/train/108/t2.nii.gz: b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xb4\xbd{\xdc\xd5'...
#
#       filename        dim_size              spacing orientation  \
# 0    t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
# 1    t2.nii.gz  (442, 442, 31)  (0.272, 0.272, 3.0)        None
# 2    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 3    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 4    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# ..         ...             ...                  ...         ...
# 134  t2.nii.gz  (442, 442, 25)  (0.272, 0.272, 3.0)        None
# 135  t2.nii.gz  (442, 442, 25)  (0.272, 0.272, 3.0)        None
# 136  t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 137  t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
# 138  t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
#
#     prostate_volume vendor mri_name psa_report
# 0              None   None     None       None
# 1              None   None     None       None
# 2              None   None     None       None
# 3              None   None     None       None
# 4              None   None     None       None
# ..              ...    ...      ...        ...
# 134            None   None     None       None
# 135            None   None     None       None
# 136            None   None     None       None
# 137            None   None     None       None
# 138            None   None     None       None
#
# [139 rows x 8 columns]
# 1.7611573049798608 seconds

# %% [markdown]
# This dataset has significantly no extra metadata information, apart from image dims

# %%
print(df)
# Out:
#       filename        dim_size              spacing orientation  \
# 0    t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
# 1    t2.nii.gz  (442, 442, 31)  (0.272, 0.272, 3.0)        None
# 2    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 3    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 4    t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# ..         ...             ...                  ...         ...
# 134  t2.nii.gz  (442, 442, 25)  (0.272, 0.272, 3.0)        None
# 135  t2.nii.gz  (442, 442, 25)  (0.272, 0.272, 3.0)        None
# 136  t2.nii.gz  (270, 270, 26)  (0.402, 0.402, 3.0)        None
# 137  t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
# 138  t2.nii.gz  (270, 270, 24)  (0.402, 0.402, 3.0)        None
#
#     prostate_volume vendor mri_name psa_report
# 0              None   None     None       None
# 1              None   None     None       None
# 2              None   None     None       None
# 3              None   None     None       None
# 4              None   None     None       None
# ..              ...    ...      ...        ...
# 134            None   None     None       None
# 135            None   None     None       None
# 136            None   None     None       None
# 137            None   None     None       None
# 138            None   None     None       None
#
# [139 rows x 8 columns]

# %% [markdown]
# Now, we are interested in the dimensons and resolutions of the data, and how they are distrubuted trough the dataset.
#
# This dataset also does not provide several anatomical orientations (axial, sagital, coronal).

# %%
    
# Obtener el conteo de dim_size y ordenarlo
dim_sizes = df['dim_size'].value_counts().sort_index(ascending=False)

# Agrupar por resolución (ancho, alto) ignorando la profundidad
resolution_counts = (
    df['dim_size']
    .apply(lambda x: (x[0], x[1]))  # Extraer solo (ancho, alto)
    .value_counts()
    .sort_index(ascending=False)
)

# Crear dos gráficos separados
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))  # Dos gráficos lado a lado

# Primer gráfico: dim_size
dim_sizes.plot(kind='bar', ax=ax1, color='blue', alpha=0.7)
ax1.set_title(f"Dim sizes (total count: {dim_sizes.sum()})")
ax1.set_xlabel("Dim Size")
ax1.set_ylabel("Count")
ax1.tick_params(axis='x', rotation=90)

# Segundo gráfico: resolución (ancho, alto)
resolution_counts.plot(kind='bar', ax=ax2, color='green', alpha=0.7)
ax2.set_title(f"Resolutions (total count: {resolution_counts.sum()})")
ax2.set_xlabel("Resolution (Width, Height)")
ax2.set_ylabel("Count")
ax2.tick_params(axis='x', rotation=70)

plt.tight_layout()  # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# Similar as before but with image voxel spacing.

# %%
value = "axial"
    
dim_sizes = df['spacing'].value_counts().sort_index(ascending=False)

# Agrupar por resolución (ancho, alto) ignorando la profundidad
resolution_counts = (
    df['spacing']
    .apply(lambda x: (x[0], x[1]))  # Extraer solo (ancho, alto)
    .value_counts()
    .sort_index(ascending=False)
)

# agrupar por la profundidad de la imagen
depth_counts = (
    df['spacing']
    .apply(lambda x: (x[2]))  # Extraer solo la profundidad
    .value_counts()
    .sort_index(ascending=False)
)


# Crear dos gráficos separados
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 8))  # Dos gráficos lado a lado

# Primer gráfico: dim_size
dim_sizes.plot(kind='bar', ax=ax1, color='blue', alpha=0.7)
ax1.set_title(f"Spacing {value} (total count: {dim_sizes.sum()})")
ax1.set_xlabel("Spacing")
ax1.set_ylabel("Count")
ax1.tick_params(axis='x', rotation=90)

# Segundo gráfico: resolución (ancho, alto)
resolution_counts.plot(kind='bar', ax=ax2, color='green', alpha=0.7)
ax2.set_title(f"Spacing {value} (x,y) (total count: {resolution_counts.sum()})")
ax2.set_xlabel("Spacing (Width, Height)")
ax2.set_ylabel("Count")
ax2.tick_params(axis='x', rotation=90)

# Tercer gráfico: profundidad
depth_counts.plot(kind='bar', ax=ax3, color='red', alpha=0.7)
ax3.set_title(f"Depth for orientation {value} (total count: {depth_counts.sum()})")
ax3.set_xlabel("Depth")
ax3.set_ylabel("Count")
ax3.tick_params(axis='x', rotation=90)

plt.tight_layout()  # Ajustar el diseño para evitar solapamientos
plt.show()

# %% [markdown]
# We must also check the image pixel intensities for normalization.

# %%
d = paths["158_train"]
dirs = list(analyzer.get_dirs(d))
random_dir = random.choices(dirs, k=3)


for idx, dir in enumerate(random_dir):
    files_in_dir = analyzer.get_files(join(d, dir), "t2.nii.gz")

    # We have to do this because get_files is a generator
    name = list(files_in_dir)[0]
    i1 = join(d, dir, name)

    analyzer.image_intensity_histogram(i1, plot = True)

# %%
interr = join(DATA_ROOT, "prostate158/interrater.csv")

df = pd.read_csv(interr)
df
# Out:
#     ID  dice_interrater_tz  dice_interrater_pz  dice_interrater_tu  \
# 0    1            0.846485            0.778402            0.634169
# 1    2            0.912788            0.708775            0.000000
# 2    3            0.918346            0.763188            0.864965
# 3    4            0.857938            0.724157            0.442276
# 4    5            0.907351            0.816965            0.778924
# 5    6            0.890938            0.780360            0.761513
# 6    7            0.901301            0.769519            0.055215
# 7    8            0.871135            0.669747            0.688969
# 8    9            0.833615            0.791664            0.324524
# 9   10            0.856498            0.792155            0.847754
# 10  11            0.864074            0.841498            0.909627
# 11  12            0.799812            0.729648            0.820766
# 12  13            0.860124            0.769509            0.600423
# 13  14            0.847756            0.820774            0.000000
# 14  15            0.895822            0.805249            0.785992
# 15  16            0.873400            0.655730            0.788047
# 16  17            0.867330            0.752174            0.711647
# 17  18            0.847408            0.589031            0.592322
# 18  19            0.927683            0.640255            0.724151
#
#     hausdorff_interrater_tz  hausdorff_interrater_pz  hausdorff_interrater_tu  \
# 0                 10.099505                 7.810250                16.155494
# 1                  8.717798                14.282857                50.338852
# 2                 11.832160                24.372115                 6.782330
# 3                  8.944272                15.937377                24.186773
# 4                  6.324555                11.045361                12.884099
# 5                  7.000000                12.569805                12.206556
# 6                 13.038405                17.691806                16.401219
# 7                 10.000000                10.816654                 5.000000
# 8                  8.602325                 8.602325                29.086079
# 9                 14.525839                43.737855                15.297059
# 10                 5.830952                17.029386                12.000000
# 11                20.223748                13.152946                 4.242641
# 12                10.099505                 9.219544                 6.164414
# 13                17.606817                22.383029                72.746134
# 14                11.832160                 9.899495                 8.485281
# 15                 9.219544                14.422205                 9.643651
# 16                15.033296                11.045361                14.247807
# 17                15.684387                24.103942                 9.000000
# 18                 7.000000                12.569805                33.075671
#
#     surface_interrater_tz  surface_interrater_pz  surface_interrater_tu  \
# 0                1.082743               0.811016               1.933039
# 1                0.572738               0.542160              27.271049
# 2                0.777702               0.386071               0.228150
# 3                1.017524               0.969512               6.120263
# 4                0.875773               0.506066               0.628945
# 5                0.804702               0.626561               0.852717
# 6                1.246122               0.597211               3.488547
# 7                0.992575               0.604556               0.585485
# 8                1.178235               0.756059               6.285089
# 9                0.969314               1.555847               0.607915
# 10               0.832017               0.809794               0.161175
# 11               1.643350               0.829752               0.445820
# 12               0.842971               0.790900               0.723659
# 13               0.958329               0.595782              45.122391
# 14               1.205393               0.436459               0.921711
# 15               1.193311               1.268889               1.070248
# 16               1.281890               0.686848               1.132854
# 17               1.325851               0.878827               1.372190
# 18               0.682835               0.488875               5.278162
#
#     tz_mean_vol_reader1  pz_mean_vol_reader1  tu_mean_vol_reader1  \
# 0                37.668               33.044                1.938
# 1                41.587               13.130                0.797
# 2                77.437               13.791                2.618
# 3                28.347               12.526                0.807
# 4                55.293               17.495                9.046
# 5                29.604               16.728               12.112
# 6                43.478               14.903                0.633
# 7                27.223               11.538                0.659
# 8                14.635               13.236                1.305
# 9                41.627               42.766               21.237
# 10               18.801               21.727                1.954
# 11               26.931               24.764                1.508
# 12               21.830               16.834                0.438
# 13               25.505               18.996                2.425
# 14               30.285               13.081                0.947
# 15               23.784               14.973                1.998
# 16               28.456               14.164                0.986
# 17               55.258               16.845                1.755
# 18               50.853                9.245                2.284
#
#     tz_mean_vol_reader2  pz_mean_vol_reader2  tu_mean_vol_reader2
# 0                38.334               38.048                1.101
# 1                42.934               18.572                0.334
# 2                77.904               18.406                2.994
# 3                26.369               14.404                0.409
# 4                55.250               21.951               10.571
# 5                31.363               17.762               14.312
# 6                38.923               20.624                0.871
# 7                26.497               20.278                0.800
# 8                12.630               15.673                1.015
# 9                44.277               42.034               24.259
# 10               19.864               21.384                2.072
# 11               26.172               25.832                1.438
# 12               20.225               16.799                0.544
# 13               25.876               21.546                1.049
# 14               27.509               15.244                0.654
# 15               21.496               13.187                1.443
# 16               27.893               15.393                0.655
# 17               48.387               21.948                1.653
# 18               47.560               12.853                1.736

# %% [markdown]
# We'll explore now the extents of the prostate in each image.
#
# We need this information to stablish how much we can center-crop the images without losing any / much information.

# %%
import concurrent.futures
# we use concurrency te prevent too many sequential reads of the files which can be slow

parent_dir = join(DATA_ROOT, paths["158_train"])
analyzer.regex = "t2_anatomy_reader"
cpus = os.cpu_count()

with concurrent.futures.ProcessPoolExecutor(
    max_workers=cpus
) as executor:
    records = list(
        executor.map(analyzer.calculate_cube_bounds, 
        analyzer.file_paths_gen(parent_dir))
    )
df = pd.DataFrame(records, columns=['start_z', 'end_z', 'start_y', 
                                    'end_y', 'start_x', 'end_x', 'mask_path',
                                    'bounding_box_size', 'proportion_of_image_size'])
df
# Out:
#      start_z  end_z  start_y  end_y  start_x  end_x  \
# 0          0     24       70    201       70    201
# 1          0     31      101    342      101    342
# 2          0     26       54    217       54    217
# 3          0     26       37    234       37    234
# 4          0     26       77    194       77    194
# ..       ...    ...      ...    ...      ...    ...
# 134        0     25      107    336      107    336
# 135        0     25      113    330      113    330
# 136        0     26       72    199       72    199
# 137        0     24       49    222       49    222
# 138        0     24       54    217       54    217
#
#                                              mask_path  bounding_box_size  \
# 0    /home/guest/work/Datasets/prostate158/prostate...                131
# 1    /home/guest/work/Datasets/prostate158/prostate...                241
# 2    /home/guest/work/Datasets/prostate158/prostate...                163
# 3    /home/guest/work/Datasets/prostate158/prostate...                197
# 4    /home/guest/work/Datasets/prostate158/prostate...                117
# ..                                                 ...                ...
# 134  /home/guest/work/Datasets/prostate158/prostate...                229
# 135  /home/guest/work/Datasets/prostate158/prostate...                217
# 136  /home/guest/work/Datasets/prostate158/prostate...                127
# 137  /home/guest/work/Datasets/prostate158/prostate...                173
# 138  /home/guest/work/Datasets/prostate158/prostate...                163
#
#      proportion_of_image_size
# 0                    0.485185
# 1                    0.545249
# 2                    0.603704
# 3                    0.729630
# 4                    0.433333
# ..                        ...
# 134                  0.518100
# 135                  0.490950
# 136                  0.470370
# 137                  0.640741
# 138                  0.603704
#
# [139 rows x 9 columns]

# %%
import random
import matplotlib.pyplot as plt

# pick a random number in the range of the dataframe and display the bounding box for the image
random_index = random.randint(0, len(df) - 1)
start_z, end_z, start_y, end_y, start_x, end_x, mask_path,\
    bounding_box_size, proportion_of_image_size = df.iloc[random_index]

mask = sitk.ReadImage(mask_path)
mask_array = sitk.GetArrayFromImage(mask)

analyzer.overlay_bounding_box(mask_array, mask_array.shape[0] //2 ,start_y, end_y, start_x, end_x)

# %%
from ipywidgets import interact, IntSlider, fixed

# Create a slider to select the slice index
slider = IntSlider(value=mask_array.shape[0] // 2, min=0, max=mask_array.shape[0]-1, step=1, description='Slice Index')
# Use interact to create the interactive bounding box display
# Note: 'fixed' is used to pass fixed values for        
# the bounding box parameters so they don't change with the slider.
interact(analyzer.overlay_bounding_box, mask=fixed(mask_array), slice=slider, start_y=fixed(start_y), end_y=fixed(end_y), start_x=fixed(start_x), end_x=fixed(end_x))
# Out:
# interactive(children=(IntSlider(value=12, description='Slice Index', max=23), Output()), _dom_classes=('widget…
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>(*args, **kwargs)>

# %% [markdown]
# Now that we have this, and since the bounding box si centered and square, we can calculate easily the distribution of the bounding box sizes in the dataset.

# %%
# using 'start_y', 'end_y', 'start_x', 'end_x', calculate the 
# size of the bounding box as the maximum of the width and height, 
# and then calculate the proportion of that wrt the image size, to 
# get a sense of how much we can crop the image


# distribution of extent proportions
df['bounding_box_size'].hist(bins=32)
plt.title("Distribution of Extent Proportions")
plt.xlabel("Extent Proportion")
plt.ylabel("Frequency")
plt.show()

df['proportion_of_image_size'].hist(bins=32)
plt.title("Distribution of Proportion of Image Size")
plt.xlabel("Proportion of Image Size")
plt.ylabel("Frequency")
plt.show()
